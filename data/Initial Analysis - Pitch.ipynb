# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
pitcher_df = pd.read_csv("Clean_Pitch.csv")
pitcher_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 0  David Aardsma  22.0  430911.0  aardsda01     2004         1     SFG    NL
# 1  David Aardsma  25.0  430911.0  aardsda01     2007         1     CHW    AL
# 2  David Aardsma  26.0  430911.0  aardsda01     2008         1     BOS    AL
# 3  David Aardsma  27.0  430911.0  aardsda01     2009         1     SEA    AL
# 4  David Aardsma  28.0  430911.0  aardsda01     2010         1     SEA    AL
#
#       salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 0   300000.0   66.675000 -0.15   -0.15   66.675000  3.764166e+05
# 1   387500.0   74.086956 -0.40   -0.40   74.086956  4.429594e+05
# 2   403250.0   83.796667 -0.31   -0.31   83.796667  4.439191e+05
# 3   419000.0  168.910000  1.69    1.69  168.910000  4.629044e+05
# 4  2750000.0  115.168421  0.68    0.68  115.168421  2.989125e+06

# %%
x_axis = pitcher_df['adjusted_sal']
war = pitcher_df['WAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1985-2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_85_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 1985)]
pitcher_85_df.head()
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 6           Don Aase  30.0  110003.0   aasedo01     1985         1     BAL
# 54         Jim Acker  26.0  110033.0  ackerji01     1985         1     TOR
# 107      Juan Agosto  27.0  110088.0  agostju01     1985         1     CHW
# 160  Doyle Alexander  34.0  110124.0  alexado01     1985         1     TOR
# 180       Neil Allen  27.0  110156.0  allenne01     1985         1     STL
#
#     lg_ID    salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 6      AL  525000.0  106.816216  0.24    0.24  106.816216  1.156449e+06
# 54     AL  170000.0  131.503226  1.17    1.17  131.503226  3.744692e+05
# 107    AL  147500.0  121.237500  0.94    0.94  121.237500  3.249071e+05
# 160    AL  875000.0  122.743000  4.81    4.81  122.743000  1.927415e+06
# 180    NL  750000.0   64.716667 -1.40   -0.82  106.175000  1.652070e+06

# %%
x_axis = pitcher_85_df['adjusted_sal']
war = pitcher_85_df['WAR']
plt.xlim(100000, 5000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1985")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_95_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 1995)]
pitcher_95_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 22    Jim Abbott  27.0  110009.0  abbotji01     1995         1     CHW    AL
# 26   Kyle Abbott  27.0  110012.0  abbotky01     1995         1     PHI    NL
# 48  Juan Acevedo  25.0  110032.0  aceveju01     1995         1     COL    NL
# 65     Mark Acre  26.0  110040.0   acrema01     1995         1     OAK    AL
# 78   Terry Adams  22.0  110067.0  adamste01     1995         1     CHC    NL
#
#        salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 22  2775000.0  133.666667  2.62    3.86  123.412820  4.315762e+06
# 26   150000.0  111.183333  0.38    0.38  111.183333  2.332844e+05
# 48   109000.0   83.500000 -0.36   -0.36   83.500000  1.695200e+05
# 65   120000.0   75.721212 -0.26   -0.26   75.721212  1.866276e+05
# 78   109000.0   63.746154 -0.39   -0.39   63.746154  1.695200e+05

# %%
x_axis = pitcher_95_df['adjusted_sal']
war = pitcher_95_df['WAR']
plt.xlim(0, 15000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1995")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_15_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 2015)]
pitcher_15_df.head()
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 15     Fernando Abad  29.0  472551.0   abadfe01     2015         1     OAK
# 68      Austin Adams  28.0  542866.0  adamsau01     2015         1     CLE
# 106   Jeremy Affeldt  36.0  346793.0  affelje01     2015         1     SFG
# 146      Matt Albers  32.0  458006.0  alberma01     2015         1     CHW
# 150  Al Alburquerque  29.0  456379.0  albural01     2015         1     DET
#
#     lg_ID     salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 15     AL  1087500.0   94.472727  0.16    0.16   94.472727     1087500.0
# 68     AL   507700.0  114.792857  0.30    0.30  114.792857      507700.0
# 106    NL  6000000.0   66.165217 -0.78   -0.78   66.165217     6000000.0
# 146    AL  1500000.0  326.300000  1.42    1.42  326.300000     1500000.0
# 150    AL  1725000.0   94.948276  0.31    0.31   94.948276     1725000.0

# %%
x_axis = pitcher_15_df['adjusted_sal']
war = pitcher_15_df['WAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_yearly_df = pitcher_df.groupby("year_ID")
avg_yearly_war = pitcher_yearly_df["WAR"].mean()
avg_yearly_war_df = pd.DataFrame(avg_yearly_war)
avg_yearly_salary = pitcher_yearly_df['adjusted_sal'].mean()
avg_yearly_salary_df = pd.DataFrame(avg_yearly_salary)
yearly_avg_df = pd.merge(avg_yearly_war_df, avg_yearly_salary_df, on="year_ID")
yearly_avg_df.head()
# Out:
#               WAR  adjusted_sal
# year_ID
# 1985     1.519447  1.001806e+06
# 1986     1.136192  8.354921e+05
# 1987     1.233716  7.984658e+05
# 1988     1.084019  7.643435e+05
# 1989     1.160065  9.122240e+05

# %%
cost_war = yearly_avg_df["adjusted_sal"]/yearly_avg_df['WAR']
cost_war
yearly_avg_df['sal/war'] = cost_war
yearly_avg_df.head()
# Out:
#               WAR  adjusted_sal        sal/war
# year_ID
# 1985     1.519447  1.001806e+06  659322.678184
# 1986     1.136192  8.354921e+05  735344.111712
# 1987     1.233716  7.984658e+05  647203.786772
# 1988     1.084019  7.643435e+05  705101.756764
# 1989     1.160065  9.122240e+05  786356.137282

# %%
x_axis = yearly_avg_df['adjusted_sal']
war = yearly_avg_df['WAR']
plt.xlim(0, 6000000)
plt.ylim(0.5,2.5)
plt.title("Avg Salary vs Avg WAR, 1985-2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = yearly_avg_df.index
data1 = yearly_avg_df['WAR']
data2 = yearly_avg_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Avg WAR', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary (2015 $)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
plt.title("Avg Cost per WAR per Year")
plt.xlabel("Year")
plt.ylabel("Avg Cost per WAR")
plt.grid()
plt.plot(yearly_avg_df['sal/war'], color="red")

# %%
team_df = pitcher_df.groupby("team_ID")
team_war = team_df["WAR"].mean()
team_war_df = pd.DataFrame(team_war)
team_war_df
team_salary = team_df['adjusted_sal'].mean()
team_salary_df = pd.DataFrame(team_salary)
combined_team_df = pd.merge(team_war_df, team_salary_df, on='team_ID')
combined_team_df.head()
# Out:
#               WAR  adjusted_sal
# team_ID
# ARI      0.936680  2.985108e+06
# ATL      1.157164  2.799761e+06
# BAL      0.838418  1.873052e+06
# BOS      1.211959  2.939585e+06
# CHC      0.890802  2.574989e+06

# %%
x_axis = combined_team_df['adjusted_sal']
war = combined_team_df['WAR']
plt.xlim(1000000, 4000000)
plt.ylim(0.5,2.0)
plt.title("Avg Team Salary vs Avg Team WAR, 1985-2015")
plt.xlabel("Avg Inflation Adjusted Salary")
plt.ylabel("Avg WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = combined_team_df.index
data1 = combined_team_df['WAR']
data2 = combined_team_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Team')
ax1.set_ylabel('Avg WAR', color=color)
ax1.bar(t, data1, color=color, alpha=0.5, align="center")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary(2015 $)', color=color)  # we already handled the x-label with ax1
ax2.bar(t, data2, color=color, alpha=0.5, align="center")
ax2.tick_params(axis='y', labelcolor=color)

# %%
stats.ttest_ind(pitcher_df.WAR, pitcher_df.adjusted_sal, equal_var=False)
# Out:
# Ttest_indResult(statistic=-71.98741442278896, pvalue=0.0)
