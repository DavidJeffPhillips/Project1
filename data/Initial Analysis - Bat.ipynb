# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats

# %%
batter_df = pd.read_csv("Clean_Bat.csv")
batter_df.head()
# Out:
#    name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 0    Andy Abad  33.0  407577.0   abadan01     2006         1     CIN    NL
# 1  Jeff Abbott  25.0  110010.0  abbotje01     1998         1     CHW    AL
# 2  Jeff Abbott  26.0  110010.0  abbotje01     1999         1     CHW    AL
# 3  Jeff Abbott  27.0  110010.0  abbotje01     2000         1     CHW    AL
# 4  Jeff Abbott  28.0  110010.0  abbotje01     2001         1     FLA    NL
#
#   pitcher    salary  OPS_plus   WAR  sumWAR  avgOPSplus   adjusted_sal
# 0       N  327000.0   14.8106 -0.02   -0.02     14.8106  384447.217262
# 1       N  175000.0  104.0026 -0.56   -0.56    104.0026  254466.104294
# 2       N  255000.0   23.1804 -0.39   -0.39     23.1804  362781.122449
# 3       N  255000.0   85.6594 -0.28   -0.28     85.6594  350983.362369
# 4       N  300000.0   74.6854  0.03    0.03     74.6854  401496.894410

# %%
x_axis = batter_df['adjusted_sal']
war = batter_df['WAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1985-2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
batter_85_df = batter_df.loc[(
    batter_df["year_ID"] == 1985)]
batter_85_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 62   Luis Aguayo  26.0  110089.0  aguaylu01     1985         1     PHI    NL
# 131   Bill Almon  32.0  110181.0  almonbi01     1985         1     PIT    NL
# 343   Tony Armas  31.0  110318.0  armasto01     1985         1     BOS    AL
# 351   Alan Ashby  33.0  110350.0  ashbyal01     1985         1     HOU    NL
# 415  Benny Ayala  34.0  110401.0  ayalabe01     1985         1     CLE    AL
#
#     pitcher    salary  OPS_plus   WAR  sumWAR  avgOPSplus  adjusted_sal
# 62        N  237000.0  132.6541  1.45    1.45    132.6541  5.220542e+05
# 131       N  255000.0  108.2203  1.55    1.55    108.2203  5.617039e+05
# 343       N  915000.0  114.1604  1.09    1.09    114.1604  2.015526e+06
# 351       N  416667.0  129.6142  1.61    1.61    129.6142  9.178175e+05
# 415       N  303333.0   91.4261 -0.25   -0.25     91.4261  6.681699e+05

# %%
x_axis = batter_85_df['adjusted_sal']
war = batter_85_df['WAR']
plt.xlim(100000, 5000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1985")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
batter_95_df = batter_df.loc[(
    batter_df["year_ID"] == 1995)]
batter_95_df.head()
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 7        Kurt Abbott  26.0  110011.0  abbotku01     1995         1     FLA
# 80      Mike Aldrete  34.0  110119.0  aldremi01     1995         1     OAK
# 83   Manny Alexander  24.0  110129.0  alexama02     1995         1     BAL
# 89   Edgardo Alfonzo  21.0  110135.0  alfoned01     1995         1     NYM
# 104      Luis Alicea  29.0  110136.0  alicelu01     1995         1     BOS
#
#     lg_ID pitcher    salary  OPS_plus   WAR  sumWAR  avgOPSplus  adjusted_sal
# 7      NL       N  119000.0  100.7859  2.01    2.01   100.78590  1.850723e+05
# 80     AL       N  430000.0  116.2834  0.59    0.49    72.55355  6.687488e+05
# 83     AL       N  130000.0   60.1196  0.00    0.00    60.11960  2.021799e+05
# 89     NL       N  109000.0   82.3578  0.69    0.69    82.35780  1.695200e+05
# 104    AL       N  800000.0   92.1503  2.28    2.28    92.15030  1.244184e+06

# %%
x_axis = batter_95_df['adjusted_sal']
war = batter_95_df['WAR']
plt.xlim(0, 15000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1995")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
batter_15_df = batter_df.loc[(
    batter_df["year_ID"] == 2015)]
batter_15_df.head()
# Out:
#             name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 39           Jose Abreu  28.0  547989.0  abreujo02     2015         1     CHW
# 47        Dustin Ackley  27.0  554429.0  ackledu01     2015         1     SEA
# 50           Matt Adams  26.0  571431.0  adamsma01     2015         1     STL
# 69           Nick Ahmed  25.0  605113.0  ahmedni01     2015         1     ARI
# 70  Arismendy Alcantara  23.0  570489.0  alcanar01     2015         1     CHC
#
#    lg_ID pitcher     salary  OPS_plus   WAR  sumWAR  avgOPSplus  adjusted_sal
# 39    AL       N  8666000.0  134.7057  3.83    3.83   134.70570     8666000.0
# 47    AL       N  2600000.0   76.9614 -1.14   -0.99   119.38925     2600000.0
# 50    NL       N   534000.0   77.5448  0.34    0.34    77.54480      534000.0
# 69    NL       N   508500.0   68.9698  2.25    2.25    68.96980      508500.0
# 70    NL       N   510000.0  -10.8200 -0.12   -0.12   -10.82000      510000.0

# %%
x_axis = batter_15_df['adjusted_sal']
war = batter_15_df['WAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
batter_yearly_df = batter_df.groupby("year_ID")
avg_yearly_war = batter_yearly_df["WAR"].mean()
avg_yearly_war_df = pd.DataFrame(avg_yearly_war)
avg_yearly_salary = batter_yearly_df['adjusted_sal'].mean()
avg_yearly_salary_df = pd.DataFrame(avg_yearly_salary)
yearly_avg_df = pd.merge(avg_yearly_war_df, avg_yearly_salary_df, on="year_ID")
yearly_avg_df.head()
# Out:
#               WAR  adjusted_sal
# year_ID
# 1985     1.564245  1.076330e+06
# 1986     1.296384  9.504198e+05
# 1987     1.284926  8.702569e+05
# 1988     1.181585  8.639058e+05
# 1989     1.237767  9.889865e+05

# %%
cost_war = yearly_avg_df["adjusted_sal"]/yearly_avg_df['WAR']
cost_war
yearly_avg_df['sal/war'] = cost_war
yearly_avg_df.head()
# Out:
#               WAR  adjusted_sal        sal/war
# year_ID
# 1985     1.564245  1.076330e+06  688082.644724
# 1986     1.296384  9.504198e+05  733131.399015
# 1987     1.284926  8.702569e+05  677281.835756
# 1988     1.181585  8.639058e+05  731141.394720
# 1989     1.237767  9.889865e+05  799008.764933

# %%
x_axis = yearly_avg_df['adjusted_sal']
war = yearly_avg_df['WAR']
plt.xlim(0, 6000000)
plt.ylim(0.5,2.5)
plt.title("Avg Salary vs Avg WAR, 1985-2015")
plt.xlabel("Inflation Adjusted Salary (2015 $)")
plt.ylabel("WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = yearly_avg_df.index
data1 = yearly_avg_df['WAR']
data2 = yearly_avg_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Avg WAR', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary (2015 $)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
plt.title("Avg Cost per WAR per Year")
plt.xlabel("Year")
plt.ylabel("Avg Cost per WAR")
plt.grid()
plt.plot(yearly_avg_df['sal/war'], color="red")

# %%
team_df = batter_df.groupby("team_ID")
team_war = team_df["WAR"].mean()
team_war_df = pd.DataFrame(team_war)
team_war_df
team_salary = team_df['adjusted_sal'].mean()
team_salary_df = pd.DataFrame(team_salary)
combined_team_df = pd.merge(team_war_df, team_salary_df, on='team_ID')
combined_team_df
# Out:
#               WAR  adjusted_sal
# team_ID
# ARI      1.045224  2.742472e+06
# ATL      1.303174  2.854794e+06
# BAL      1.282551  2.798060e+06
# BOS      1.514501  3.683337e+06
# CHC      1.002758  2.897048e+06
# CHW      1.213845  2.740406e+06
# CIN      1.113648  2.211074e+06
# CLE      1.335603  2.157153e+06
# COL      1.036833  2.916815e+06
# DET      1.403448  3.146500e+06
# FLA      0.921743  1.622961e+06
# HOU      1.163432  2.341310e+06
# KCR      0.893884  1.832791e+06
# LAA      1.352766  2.744832e+06
# LAD      0.977460  3.248814e+06
# MIA      0.599815  1.910257e+06
# MIL      1.096307  1.978815e+06
# MIN      1.140366  2.034983e+06
# NYM      1.163755  3.137881e+06
# NYY      1.620230  5.338424e+06
# OAK      1.341596  2.004989e+06
# PHI      1.177246  2.780876e+06
# PIT      1.004322  1.724036e+06
# SDP      1.040169  1.935522e+06
# SEA      1.303768  2.799795e+06
# SFG      1.376115  2.833008e+06
# STL      1.425146  2.789889e+06
# TBD      0.868000  1.962034e+06
# TBR      1.730345  2.547272e+06
# TEX      1.421447  2.946920e+06
# TOR      1.461290  2.619353e+06
# WSN      0.911543  1.871319e+06

# %%
x_axis = combined_team_df['adjusted_sal']
war = combined_team_df['WAR']
plt.xlim(1000000, 4000000)
plt.ylim(0.5,2.0)
plt.title("Avg Team Salary vs Avg Team WAR, 1985-2015")
plt.xlabel("Avg Inflation Adjusted Salary")
plt.ylabel("Avg WAR")
plt.grid()

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = combined_team_df.index
data1 = combined_team_df['WAR']
data2 = combined_team_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Team')
ax1.set_ylabel('Avg WAR', color=color)
ax1.bar(t, data1, color=color, alpha=0.5, align="center")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary(2015 $)', color=color)  # we already handled the x-label with ax1
ax2.bar(t, data2, color=color, alpha=0.5, align="center")
ax2.tick_params(axis='y', labelcolor=color)

# %%
stats.ttest_ind(batter_df.WAR, batter_df.adjusted_sal, equal_var=False)
# Out:
# Ttest_indResult(statistic=-77.68641403938095, pvalue=0.0)
