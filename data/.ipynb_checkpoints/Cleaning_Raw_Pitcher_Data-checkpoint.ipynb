# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pitch_war_raw_df = pd.read_csv("war_daily_pitch.csv")
pitch_war_raw_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID  \
# 0  David Aardsma  22.0  430911.0  aardsda01     2004     SFG         1    NL
# 1  David Aardsma  24.0  430911.0  aardsda01     2006     CHC         1    NL
# 2  David Aardsma  25.0  430911.0  aardsda01     2007     CHW         1    AL
# 3  David Aardsma  26.0  430911.0  aardsda01     2008     BOS         1    AL
# 4  David Aardsma  27.0  430911.0  aardsda01     2009     SEA         1    AL
#
#     G  GS   ...    pyth_exponent  waa_win_perc     WAA  WAA_adj  oppRpG_rep  \
# 0  11   0   ...            1.902        0.4803 -0.2167  -0.0298     4.75633
# 1  45   0   ...            1.909        0.5060  0.2700  -0.1301     4.97303
# 2  25   0   ...            1.924        0.4781 -0.5475  -0.1994     5.00394
# 3  47   0   ...            1.904        0.4836 -0.7708  -0.0631     4.81624
# 4  73   0   ...            1.899        0.5105  0.7665   0.1581     4.90529
#
# ...

# %%
CleanPitch_df = pitch_war_raw_df[["name_common","age","mlb_ID", "player_ID","year_ID","stint_ID","team_ID","lg_ID","salary","ERA_plus","WAR"]]
CleanPitch_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 0  David Aardsma  22.0  430911.0  aardsda01     2004         1     SFG    NL
# 1  David Aardsma  24.0  430911.0  aardsda01     2006         1     CHC    NL
# 2  David Aardsma  25.0  430911.0  aardsda01     2007         1     CHW    AL
# 3  David Aardsma  26.0  430911.0  aardsda01     2008         1     BOS    AL
# 4  David Aardsma  27.0  430911.0  aardsda01     2009         1     SEA    AL
#
#      salary    ERA_plus   WAR
# 0  300000.0   66.675000 -0.15
# 1       NaN  114.295833  0.61
# 2  387500.0   74.086956 -0.40
# 3  403250.0   83.796667 -0.31
# 4  419000.0  168.910000  1.69

# %%
CleanPitch_df = CleanPitch_df[CleanPitch_df["year_ID"]>1975]
CleanPitch_df = CleanPitch_df[CleanPitch_df["year_ID"]<2017]
CleanPitch_df
# Out:
#              name_common   age    mlb_ID  player_ID  year_ID  stint_ID  \
# 0          David Aardsma  22.0  430911.0  aardsda01     2004         1
# 1          David Aardsma  24.0  430911.0  aardsda01     2006         1
# 2          David Aardsma  25.0  430911.0  aardsda01     2007         1
# 3          David Aardsma  26.0  430911.0  aardsda01     2008         1
# 4          David Aardsma  27.0  430911.0  aardsda01     2009         1
# 5          David Aardsma  28.0  430911.0  aardsda01     2010         1
# 6          David Aardsma  30.0  430911.0  aardsda01     2012         1
# 7          David Aardsma  31.0  430911.0  aardsda01     2013         1
# 8          David Aardsma  33.0  430911.0  aardsda01     2015         1
# 9               Don Aase  22.0  110003.0   aasedo01     1977         1
# 10              Don Aase  23.0  110003.0   aasedo01     1978         1
# 11              Don Aase  24.0  110003.0   aasedo01     1979         1
# ...

# %%
CleanPitch_df.to_csv("Clean_Pitch.csv", index=False)
