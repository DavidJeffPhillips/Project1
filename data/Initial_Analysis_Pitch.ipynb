# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import scipy.stats as stats

# %%
pitcher_df = pd.read_csv("Clean_Pitch.csv")
pitcher_df.head()
# Out:
#      name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID lg_ID  \
# 0  David Aardsma  22.0  430911.0  aardsda01     2004         1     SFG    NL
# 1  David Aardsma  25.0  430911.0  aardsda01     2007         1     CHW    AL
# 2  David Aardsma  26.0  430911.0  aardsda01     2008         1     BOS    AL
# 3  David Aardsma  27.0  430911.0  aardsda01     2009         1     SEA    AL
# 4  David Aardsma  28.0  430911.0  aardsda01     2010         1     SEA    AL
#
#       salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 0   300000.0   66.675000 -0.15   -0.15   66.675000  3.811652e+05
# 1   387500.0   74.086956 -0.40   -0.40   74.086956  4.485474e+05
# 2   403250.0   83.796667 -0.31   -0.31   83.796667  4.495192e+05
# 3   419000.0  168.910000  1.69    1.69  168.910000  4.687440e+05
# 4  2750000.0  115.168421  0.68    0.68  115.168421  3.026834e+06

# %%
x_axis = pitcher_df['adjusted_sal']
war = pitcher_df['WAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1986-2016")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")


plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_86_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 1986)]
pitcher_86_df.head()
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 6           Don Aase  31.0  110003.0   aasedo01     1986         1     BAL
# 54         Jim Acker  27.0  110033.0  ackerji01     1986         2     ATL
# 112    Rick Aguilera  24.0  110090.0  aguilri01     1986         1     NYM
# 160  Doyle Alexander  35.0  110124.0  alexado01     1986         1     TOR
# 180       Neil Allen  28.0  110156.0  allenne01     1986         1     CHW
#
#     lg_ID    salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 6      AL  600000.0  139.907407  2.27    2.27  139.907407  1.313907e+06
# 54     NL  367500.0  104.635000  1.28    1.28  101.207155  8.047680e+05
# 112    NL  130000.0   92.567213  0.44    0.44   92.567213  2.846798e+05
# 160    AL  700000.0   95.118182  1.29    3.15   99.212091  1.532891e+06
# 180    AL  900000.0  114.231250  1.89    1.89  114.231250  1.970860e+06

# %%
x_axis = pitcher_86_df['adjusted_sal']
war = pitcher_86_df['sumWAR']
plt.xlim(100000, 5000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1986")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_96_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 1996)]
pitcher_96_df.head()
# Out:
#        name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 23      Jim Abbott  28.0  110009.0  abbotji01     1996         1     LAA
# 65       Mark Acre  27.0  110040.0   acrema01     1996         1     OAK
# 78     Terry Adams  23.0  110067.0  adamste01     1996         1     CHC
# 88    Willie Adams  23.0  110068.0  adamswi02     1996         1     OAK
# 122  Rick Aguilera  34.0  110090.0  aguilri01     1996         1     MIN
#
#     lg_ID     salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 23     AL  2200000.0   65.650000 -2.08   -2.08   65.650000  3.365299e+06
# 65     AL   140000.0   84.317647  0.06    0.06   84.317647  2.141554e+05
# 78     NL   113000.0  146.996970  1.74    1.74  146.996970  1.728540e+05
# 88     AL   109000.0  127.700000  1.82    1.82  127.700000  1.667353e+05
# 122    AL  3500000.0   94.398507  0.79    0.79   94.398507  5.353885e+06

# %%
x_axis = pitcher_96_df['adjusted_sal']
war = pitcher_96_df['sumWAR']
plt.xlim(0, 15000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 1996")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_06_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 2006)]
pitcher_06_df.head()
# Out:
#            name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 35      Jeremy Accardo  24.0  435618.0  accarje01     2006         1     SFG
# 96      Jeremy Affeldt  27.0  346793.0  affelje01     2006         1     KCR
# 174  Antonio Alfonseca  34.0  110134.0  alfonan01     2006         1     TEX
# 292        Greg Aquino  28.0  425628.0  aquingr01     2006         1     ARI
# 312         Tony Armas  28.0  150393.0  armasto02     2006         1     WSN
#
#     lg_ID     salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 35     NL   330000.0   92.322727 -0.11   -0.32   84.866627  3.928686e+05
# 96     AL  1000000.0   79.856522 -0.51   -1.21   75.756832  1.190511e+06
# 174    AL  2750000.0   83.650000 -0.06   -0.06   83.650000  3.273905e+06
# 292    NL   342000.0  106.304167  0.23    0.23  106.304167  4.071547e+05
# 312    NL  2100000.0   85.148837  0.67    0.67   85.148837  2.500073e+06

# %%
x_axis = pitcher_06_df['adjusted_sal']
war = pitcher_06_df['sumWAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 2006")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_16_df = pitcher_df.loc[(
    pitcher_df["year_ID"] == 2016)]
pitcher_16_df.head()
# Out:
#          name_common   age    mlb_ID  player_ID  year_ID  stint_ID team_ID  \
# 15     Fernando Abad  30.0  472551.0   abadfe01     2016         2     BOS
# 145      Matt Albers  33.0  458006.0  alberma01     2016         1     CHW
# 150  Al Alburquerque  30.0  456379.0  albural01     2016         1     LAA
# 179       Cody Allen  27.0  592102.0  allenco01     2016         1     CLE
# 202     Jose Alvarez  27.0  501625.0  alvarjo02     2016         1     LAA
#
#     lg_ID     salary    ERA_plus   WAR  sumWAR  avgERAplus  adjusted_sal
# 15     AL  1250000.0   71.633333 -0.27    0.77  116.146667     1250000.0
# 145    AL  2000000.0   64.472222 -1.91   -1.91   64.472222     2000000.0
# 150    AL  1100000.0  105.800000 -0.11   -0.11  105.800000     1100000.0
# 179    AL  4150000.0  179.936842  1.84    1.84  179.936842     4150000.0
# 202    AL   519500.0  116.522727  0.02    0.02  116.522727      519500.0

# %%
x_axis = pitcher_16_df['adjusted_sal']
war = pitcher_16_df['sumWAR']
plt.xlim(0, 30000000)
plt.ylim(-5,13)
plt.title("Salary vs WAR, 2016")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
pitcher_yearly_df = pitcher_df.groupby("year_ID")
avg_yearly_war = pitcher_yearly_df["sumWAR"].mean()
avg_yearly_war_df = pd.DataFrame(avg_yearly_war)
avg_yearly_salary = pitcher_yearly_df['adjusted_sal'].mean()
avg_yearly_salary_df = pd.DataFrame(avg_yearly_salary)
yearly_avg_df = pd.merge(avg_yearly_war_df, avg_yearly_salary_df, on="year_ID")
yearly_avg_df.head()
# Out:
#            sumWAR   adjusted_sal
# year_ID
# 1986     1.182848  846031.976900
# 1987     1.264392  808538.555992
# 1988     1.114891  773985.775355
# 1989     1.197055  923731.839608
# 1990     0.882020  859636.511568

# %%
cost_war = yearly_avg_df["adjusted_sal"]/yearly_avg_df['sumWAR']
cost_war
yearly_avg_df['sal/war'] = cost_war
yearly_avg_df.head()
# Out:
#            sumWAR   adjusted_sal        sal/war
# year_ID
# 1986     1.182848  846031.976900  715250.145635
# 1987     1.264392  808538.555992  639468.317677
# 1988     1.114891  773985.775355  694225.533388
# 1989     1.197055  923731.839608  771670.330203
# 1990     0.882020  859636.511568  974622.247426

# %%
x_axis = yearly_avg_df['adjusted_sal']
war = yearly_avg_df['sumWAR']
plt.xlim(0, 6000000)
plt.ylim(0.5,2.5)
plt.title("Avg Salary vs Avg WAR, 1986-2016")
plt.xlabel("Inflation Adjusted Salary (2016 $)")
plt.ylabel("WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = yearly_avg_df.index
data1 = yearly_avg_df['sumWAR']
data2 = yearly_avg_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Year')
ax1.set_ylabel('Avg WAR', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary (2015 $)', color=color)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)
ax2.tick_params(axis='y', labelcolor=color)

# %%
plt.title("Avg Cost per WAR per Year")
plt.xlabel("Year")
plt.ylabel("Avg Cost per WAR")
plt.grid()
plt.plot(yearly_avg_df['sal/war'], color="red")

# %%
team_df = pitcher_df.groupby("team_ID")
team_war = team_df["sumWAR"].mean()
team_war_df = pd.DataFrame(team_war)
team_war_df
team_salary = team_df['adjusted_sal'].mean()
team_salary_df = pd.DataFrame(team_salary)
combined_team_df = pd.merge(team_war_df, team_salary_df, on='team_ID')
combined_team_df.head()
# Out:
#            sumWAR  adjusted_sal
# team_ID
# ARI      0.947500  3.093495e+06
# ATL      1.191687  2.828884e+06
# BAL      0.895240  1.982198e+06
# BOS      1.223562  3.133548e+06
# CHC      0.928744  2.807950e+06

# %%
x_axis = combined_team_df['adjusted_sal']
war = combined_team_df['sumWAR']
plt.xlim(1000000, 4000000)
plt.ylim(0.5,2.0)
plt.title("Avg Team Salary vs Avg Team WAR, 1985-2015")
plt.xlabel("Avg Inflation Adjusted Salary")
plt.ylabel("Avg WAR")
plt.grid()

z = np.polyfit(x_axis, war, 1)
p = np.poly1d(z)
plt.plot(x_axis,p(x_axis),"r--")

plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25)

#plt.savefig("salary_vs_war.png")

plt.show()

# %%
t = combined_team_df.index
data1 = combined_team_df['sumWAR']
data2 = combined_team_df['adjusted_sal']

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Team')
ax1.set_ylabel('Avg WAR', color=color)
ax1.bar(t, data1, color=color, alpha=0.5, align="center")
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Avg Inflation Adjusted Salary(2015 $)', color=color)  # we already handled the x-label with ax1
ax2.bar(t, data2, color=color, alpha=0.5, align="center")
ax2.tick_params(axis='y', labelcolor=color)

# %%
team_df = pitcher_df.groupby(["team_ID", "year_ID"])
team_df.head()
yearly_team_war = team_df['sumWAR'].sum()
yearly_team_war
yearly_team_sal = team_df['adjusted_sal'].sum()
yearly_team_sal
yearly_costof_war = yearly_team_sal/yearly_team_war
yearly_costof_war
yearly_sal_war_df = pd.DataFrame({"Yearly War by Team": yearly_team_war,
                           "Yearly Salary by Team": yearly_team_sal,
                           "Yearly cost of WAR by Team": yearly_costof_war})
yearly_sal_war_df.head()

new = yearly_sal_war_df["Yearly cost of WAR by Team"]
new_df = pd.DataFrame(new)
new_df.head()
# Out:
#                  Yearly cost of WAR by Team
# team_ID year_ID
# ARI     1998                   3.449858e+06
#         1999                   2.198888e+06
#         2000                   3.995147e+06
#         2001                   1.952730e+06
#         2002                   2.957837e+06

# %%
# %matplotlib notebook
new_df.unstack(level=0).plot(legend=False)
#plt.ylim(-1000000,30000000)
plt.figure(figsize=(50,50))
# plt.yticks(rotation=45)
# plt.legend(bbox_to_anchor=(1,1))
# new_df.plot(legend=n)
plt.show()

# %%
years = [1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016]
correlations = []
for year in years:
    pitcheryear_df = pitcher_df.loc[(pitcher_df["year_ID"] == year)]
    x_axis = pitcheryear_df['adjusted_sal']
    war = pitcheryear_df['sumWAR']
    z = np.polyfit(x_axis, war, 1)
    p = np.poly1d(z)
    plt.plot(x_axis,p(x_axis),"r--")
    plt.scatter(x_axis, war, marker="o", s=50, alpha=0.25,edgecolor='black', color='blue')
    correlationyear = np.corrcoef(x_axis, war) [0,1]
    correlationyear = correlationyear**2
    correlations.append(correlationyear)


correlations
# Out:
# [0.028370831964485928,
#  0.08400103784397714,
#  0.05524211935076926,
#  0.08483534451185855,
#  0.10011392512367502,
#  0.054145005743714045,
#  0.1407578859916977,
#  0.1733997052830531,
#  0.14514894562992922,
#  0.18599571325477943,
#  0.2297314663154371,
#  0.2171407666364008,
#  0.23853187682314148,
#  0.1834462558028521,
#  0.14788717731932702,
#  0.12348296774997433,
#  0.07318602926209039,
#  0.09674712049243055,
#  0.1367145376977216,
#  0.1107530296199231,
#  0.11791859624626586,
#  0.07399300826432564,
#  0.07180537116980476,
#  0.09446218183443933,
#  0.06400274282411304,
#  0.10151656269165044,
#  0.08821835033810245,
#  0.05149144783913942,
#  0.07016320734453092,
#  0.103402916369425,
#  0.09537537803383671]

# %%
plt.plot(years, correlations)
plt.title("Correlation between WAR and adjusted salary between 1986 and 2016")
plt.xlabel("Year")
plt.ylabel("R-squared of adjusted salary and WAR")
plt.grid()
